# %%
# 测试代码, 生成成功

print("hello world")
# Out:
# hello world

# %%
# 创建一个空的df

import pandas as pd

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # 此处为新建markdown

# %% [markdown]
# ## 此处为次级标题
